# %%
import matplotlib.pyplot as plt

# SEED VALUE
X0 = 1  # RANDU: Sequence A096555 in the OEIS: https://oeis.org/A096555
SIZE = 10000
A = 65539  # MULTIPLICATIVE FACTOR
C = 0  # ADDITIVE FACTOR
M = 2**31  # MODULUS FACTOR

class RANDU:
    "Pseudorandom number generator RANDU, a (flawed) linear congruential PRNG."

    def __init__(self):
        self._state = X0

    def random(self):
        self._state = (A * self._state + C) % M
        return self._state / M

prng = RANDU()
x = []
y = []
z = []

for i in range(SIZE):
    x.append(prng.random())
    y.append(prng.random())
    z.append(prng.random())

fig = plt.figure(f'RANDU, points: {SIZE}')
ax = fig.add_axes([0, 0, 1, 1], projection='3d')  # use 3d plotting

# ----------------------------layout-------------------------------------
plt.style.use('ggplot')
fig.set_facecolor('w')
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
# -----------------------------------------------------------------------

ax.plot(x, y, z, '.', color='#006F00')
ax.view_init(90, -90)  # set initial view
plt.suptitle(f'X: 90')
plt.draw()
plt.pause(2)  # wait 2 secs, then start rotating

for angle in range(0, 361):  # rotate the view
    plt.suptitle(f'X: {angle}')
    ax.view_init(angle, -45 + (angle // 5))
    plt.draw()
    plt.pause(0.3)
plt.pause(2)

for i in range(20):
    ax.view_init(85 + i, -45)
    plt.suptitle(f'The Planes: X: {85 + i}')
    plt.draw()
    plt.pause(0.3)
plt.pause(2)

ax.view_init(97, 0)
plt.suptitle(f'The Planes: X: 97')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 50
#      48     ax.view_init(angle, -45 + (angle // 5))
#      49     plt.draw()
# ---> 50     plt.pause(0.3)
#      51 plt.pause(2)
#      53 for i in range(20):
#
# File ~/miniconda3/lib/python3.11/site-packages/matplotlib/pyplot.py:582, in pause(interval)
#     580         canvas.draw_idle()
#     581     show(block=False)
# --> 582     canvas.start_event_loop(interval)
#     583 else:
#     584     time.sleep(interval)
#
# File ~/miniconda3/lib/python3.11/site-packages/matplotlib/backend_bases.py:2553, in FigureCanvasBase.start_event_loop(self, timeout)
#    2551 while self._looping and counter * timestep < timeout:
#    2552     self.flush_events()
# -> 2553     time.sleep(timestep)
#    2554     counter += 1
#
# KeyboardInterrupt:

# %%
import sys
